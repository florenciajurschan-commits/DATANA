# %% [markdown]
# <a href="https://colab.research.google.com/github/florenciajurschan-commits/DATANA/blob/main/SQL_vs_Pandas_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Introducción
#
#
# * Breve descripción general de Pandas y su importancia.
# * Discusión sobre SQL y su relación con las operaciones de Pandas DataFrame.

# %% [markdown]
# # 2. Setup

# %%
import sqlite3 # a module in Python's standard library that provides an interface to the SQLite database.
import pandas as pd

# %%
url = "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"
titanic_data = pd.read_csv(url)

# %%
conn = sqlite3.connect(':memory:')
titanic_data.to_sql('titanic', conn, index=False)
# Out:
# 887

# %% [markdown]
# **sqlite3.connect()** es una función que establece una conexión a una base de datos SQLite. Cuando se proporciona el argumento ':memory:', se le indica a SQLite que cree una nueva base de datos en la RAM. La principal ventaja de utilizar una base de datos en memoria es la velocidad.

# %% [markdown]
# **.to_sql()** es un método proporcionado por Pandas DataFrames que le permite escribir el contenido del DataFrame en una base de datos SQL.
#
# El primer argumento 'titanic' es el nombre de la tabla que se creará en la base de datos SQLite.
#
# El segundo argumento conn es el objeto de conexión que creamos anteriormente. Le indica al método .to_sql() dónde crear la tabla.
#
# El argumento index=False le indica a Pandas que no escriba el índice del DataFrame como una columna separada en la base de datos. Si omitiera este argumento, obtendría una columna adicional llamada 'index' en su tabla SQL.

# %% [markdown]
# Función para ejecutar las queries (solamente ejecutarlo, no dará resultado)

# %%
# Function to run querys
def run_query(query, connection=conn):
    return pd.read_sql_query(query, connection)

# %% [markdown]
# # 3. SQL vs. Pandas

# %% [markdown]
# Para **SQL** nuestra tabla se llama *titanic*
#
# Para **pandas** nuestro df se llama *titanic_data*

# %%
#Veo mis datos
titanic_data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0      male  22.0                        1                        0   7.2500
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 4      male  35.0                        0                        0   8.0500
# ..      ...   ...                      ...                      ...      ...
# 882    male  27.0                        0                        0  13.0000
# 883  female  19.0                        0                        0  30.0000
# 884  female   7.0                        1                        2  23.4500
# 885    male  26.0                        0                        0  30.0000
# 886    male  32.0                        0                        0   7.7500
#
# [887 rows x 8 columns]

# %% [markdown]
# *   **Ver los nombres de 10 pasajeros**

# %%
# Usando SQL

run_query(
"""
select name from titanic limit 10


"""

 )
# Out:
#                                                 Name
# 0                             Mr. Owen Harris Braund
# 1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2                              Miss. Laina Heikkinen
# 3        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4                            Mr. William Henry Allen
# 5                                    Mr. James Moran
# 6                             Mr. Timothy J McCarthy
# 7                      Master. Gosta Leonard Palsson
# 8   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9                 Mrs. Nicholas (Adele Achem) Nasser

# %%
# Usando Pandas

titanic_data['Name'].head(10)
# Out:
# 0                               Mr. Owen Harris Braund
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2                                Miss. Laina Heikkinen
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4                              Mr. William Henry Allen
# 5                                      Mr. James Moran
# 6                               Mr. Timothy J McCarthy
# 7                        Master. Gosta Leonard Palsson
# 8     Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9                   Mrs. Nicholas (Adele Achem) Nasser
# Name: Name, dtype: object

# %% [markdown]
# **¿Cuántas clases diferentes hay?**

# %%
# Usando SQL

run_query(
"""
select distinct pclass from titanic

"""
    )
# Out:
#    Pclass
# 0       3
# 1       1
# 2       2

# %%
# Usando Pandas
titanic_data['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# **Mostrar los pasajeros ordenados por edad**

# %%
# Usando SQL

run_query(
"""
select * from titanic order by age


"""
    )
# Out:
#      Survived  Pclass                                 Name     Sex    Age  \
# 0           1       3       Master. Assad Alexander Thomas    male   0.42
# 1           1       2             Master. Viljo Hamalainen    male   0.67
# 2           1       3         Miss. Helene Barbara Baclini  female   0.75
# 3           1       3                Miss. Eugenie Baclini  female   0.75
# 4           1       2         Master. Alden Gates Caldwell    male   0.83
# ..        ...     ...                                  ...     ...    ...
# 882         0       3                  Mr. Patrick Connors    male  70.50
# 883         0       1             Mr. George B Goldschmidt    male  71.00
# 884         0       1               Mr. Ramon Artagaveytia    male  71.00
# 885         0       3                   Mr. Johan Svensson    male  74.00
# 886         1       1  Mr. Algernon Henry Wilson Barkworth    male  80.00
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0                          0                        1   8.5167
# 1                          1                        1  14.5000
# 2                          2                        1  19.2583
# 3                          2                        1  19.2583
# 4                          0                        2  29.0000
# ..                       ...                      ...      ...
# 882                        0                        0   7.7500
# 883                        0                        0  34.6542
# 884                        0                        0  49.5042
# 885                        0                        0   7.7750
# 886                        0                        0  30.0000
#
# [887 rows x 8 columns]

# %%
# Usando Pandas
titanic_data.sort_values(by='Age')
# Out:
#      Survived  Pclass                                 Name     Sex    Age  \
# 799         1       3       Master. Assad Alexander Thomas    male   0.42
# 751         1       2             Master. Viljo Hamalainen    male   0.67
# 641         1       3                Miss. Eugenie Baclini  female   0.75
# 466         1       3         Miss. Helene Barbara Baclini  female   0.75
# 77          1       2         Master. Alden Gates Caldwell    male   0.83
# ..        ...     ...                                  ...     ...    ...
# 115         0       3                  Mr. Patrick Connors    male  70.50
# 490         0       1               Mr. Ramon Artagaveytia    male  71.00
# 95          0       1             Mr. George B Goldschmidt    male  71.00
# 847         0       3                   Mr. Johan Svensson    male  74.00
# 627         1       1  Mr. Algernon Henry Wilson Barkworth    male  80.00
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 799                        0                        1   8.5167
# 751                        1                        1  14.5000
# 641                        2                        1  19.2583
# 466                        2                        1  19.2583
# 77                         0                        2  29.0000
# ..                       ...                      ...      ...
# 115                        0                        0   7.7500
# 490                        0                        0  49.5042
# 95                         0                        0  34.6542
# 847                        0                        0   7.7750
# 627                        0                        0  30.0000
#
# [887 rows x 8 columns]

# %% [markdown]
# **Mostrar los pasajeros que sobrevivieron**

# %%
# Usando SQL

run_query(
"""
select *
from titanic
where survived = 1

"""
    )
# Out:
#      Survived  Pclass                                               Name  \
# 0           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 1           1       3                              Miss. Laina Heikkinen
# 2           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 3           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 4           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# ..        ...     ...                                                ...
# 337         1       3                           Miss. Adele Kiamie Najib
# 338         1       1       Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
# 339         1       2        Mrs. William (Imanita Parrish Hall) Shelley
# 340         1       1                        Miss. Margaret Edith Graham
# 341         1       1                               Mr. Karl Howell Behr
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    female  38.0                        1                        0  71.2833
# 1    female  26.0                        0                        0   7.9250
# 2    female  35.0                        1                        0  53.1000
# 3    female  27.0                        0                        2  11.1333
# 4    female  14.0                        1                        0  30.0708
# ..      ...   ...                      ...                      ...      ...
# 337  female  15.0                        0                        0   7.2250
# 338  female  56.0                        0                        1  83.1583
# 339  female  25.0                        0                        1  26.0000
# 340  female  19.0                        0                        0  30.0000
# 341    male  26.0                        0                        0  30.0000
#
# [342 rows x 8 columns]

# %%
# Usando Pandas
titanic_data[titanic_data['Survived'] == 1]
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# ..        ...     ...                                                ...
# 871         1       3                           Miss. Adele Kiamie Najib
# 875         1       1       Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
# 876         1       2        Mrs. William (Imanita Parrish Hall) Shelley
# 883         1       1                        Miss. Margaret Edith Graham
# 885         1       1                               Mr. Karl Howell Behr
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 8    female  27.0                        0                        2  11.1333
# 9    female  14.0                        1                        0  30.0708
# ..      ...   ...                      ...                      ...      ...
# 871  female  15.0                        0                        0   7.2250
# 875  female  56.0                        0                        1  83.1583
# 876  female  25.0                        0                        1  26.0000
# 883  female  19.0                        0                        0  30.0000
# 885    male  26.0                        0                        0  30.0000
#
# [342 rows x 8 columns]

# %% [markdown]
# **Mostrar los pasajeros que no sobrevivieron y tenían menos de 30 años**

# %%
# Usando SQL

run_query(
"""
select * from titanic where survived = 0 and age < 30

"""
    )
# Out:
#      Survived  Pclass                                 Name     Sex   Age  \
# 0           0       3               Mr. Owen Harris Braund    male  22.0
# 1           0       3                      Mr. James Moran    male  27.0
# 2           0       3        Master. Gosta Leonard Palsson    male   2.0
# 3           0       3        Mr. William Henry Saundercock    male  20.0
# 4           0       3  Miss. Hulda Amanda Adolfina Vestrom  female  14.0
# ..        ...     ...                                  ...     ...   ...
# 300         0       3          Miss. Gerda Ulrika Dahlberg  female  22.0
# 301         0       2         Mr. Frederick James Banfield    male  28.0
# 302         0       3                Mr. Henry Jr Sutehall    male  25.0
# 303         0       2                 Rev. Juozas Montvila    male  27.0
# 304         0       3       Miss. Catherine Helen Johnston  female   7.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0                          1                        0   7.2500
# 1                          0                        0   8.4583
# 2                          3                        1  21.0750
# 3                          0                        0   8.0500
# 4                          0                        0   7.8542
# ..                       ...                      ...      ...
# 300                        0                        0  10.5167
# 301                        0                        0  10.5000
# 302                        0                        0   7.0500
# 303                        0                        0  13.0000
# 304                        1                        2  23.4500
#
# [305 rows x 8 columns]

# %%
# Usando Pandas

titanic_data[titanic_data['Survived']==1]
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# ..        ...     ...                                                ...
# 871         1       3                           Miss. Adele Kiamie Najib
# 875         1       1       Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
# 876         1       2        Mrs. William (Imanita Parrish Hall) Shelley
# 883         1       1                        Miss. Margaret Edith Graham
# 885         1       1                               Mr. Karl Howell Behr
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 8    female  27.0                        0                        2  11.1333
# 9    female  14.0                        1                        0  30.0708
# ..      ...   ...                      ...                      ...      ...
# 871  female  15.0                        0                        0   7.2250
# 875  female  56.0                        0                        1  83.1583
# 876  female  25.0                        0                        1  26.0000
# 883  female  19.0                        0                        0  30.0000
# 885    male  26.0                        0                        0  30.0000
#
# [342 rows x 8 columns]

# %% [markdown]
# Mostrar pasajeron que tienen entre 30 y 50 años

# %%
# Usando SQL

run_query(
"""
select * from titanic where age between 30 and 50

"""
    )
# Out:
#      Survived  Pclass                                               Name  \
# 0           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 1           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 2           0       3                            Mr. William Henry Allen
# 3           0       3                         Mr. Anders Johan Andersson
# 4           0       3  Mrs. Julius (Emelia Maria Vandemoortele) Vande...
# ..        ...     ...                                                ...
# 318         0       1                            Mr. Frans Olof Carlsson
# 319         0       3                         Mr. Victor Vander Cruyssen
# 320         0       3                                  Mr. Johann Markun
# 321         0       3                Mrs. William (Margaret Norton) Rice
# 322         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    female  38.0                        1                        0  71.2833
# 1    female  35.0                        1                        0  53.1000
# 2      male  35.0                        0                        0   8.0500
# 3      male  39.0                        1                        5  31.2750
# 4    female  31.0                        1                        0  18.0000
# ..      ...   ...                      ...                      ...      ...
# 318    male  33.0                        0                        0   5.0000
# 319    male  47.0                        0                        0   9.0000
# 320    male  33.0                        0                        0   7.8958
# 321  female  39.0                        0                        5  29.1250
# 322    male  32.0                        0                        0   7.7500
#
# [323 rows x 8 columns]

# %%
# Usando Pandas

titanic_data[titanic_data['Age']>=30][titanic_data['Age']<=50]
# Out:
# /tmp/ipykernel_3701/3325138178.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic_data[titanic_data['Age']>=30][titanic_data['Age']<=50]
#      Survived  Pclass                                               Name  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# 13          0       3                         Mr. Anders Johan Andersson
# 18          0       3  Mrs. Julius (Emelia Maria Vandemoortele) Vande...
# ..        ...     ...                                                ...
# 868         0       1                            Mr. Frans Olof Carlsson
# 869         0       3                         Mr. Victor Vander Cruyssen
# 877         0       3                                  Mr. Johann Markun
# 881         0       3                Mrs. William (Margaret Norton) Rice
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 1    female  38.0                        1                        0  71.2833
# 3    female  35.0                        1                        0  53.1000
# 4      male  35.0                        0                        0   8.0500
# 13     male  39.0                        1                        5  31.2750
# 18   female  31.0                        1                        0  18.0000
# ..      ...   ...                      ...                      ...      ...
# 868    male  33.0                        0                        0   5.0000
# 869    male  47.0                        0                        0   9.0000
# 877    male  33.0                        0                        0   7.8958
# 881  female  39.0                        0                        5  29.1250
# 886    male  32.0                        0                        0   7.7500
#
# [323 rows x 8 columns]

# %% [markdown]
# **¿Cuántos pasajeros se llaman 'John'?**

# %%
# Usando SQL

run_query(
"""
select * from titanic where name like '%John%'

"""
    )
# Out:
#     Survived  Pclass                                               Name  \
# 0          1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 1          1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 2          0       2  Mrs. William John Robert (Dorothy Ann Wonnacot...
# 3          0       3                            Mr. William John Rogers
# 4          1       2                Mrs. John T (Ada Julia Bone) Doling
# 5          0       3                              Mr. David John Barton
# 6          0       2                     Mr. William John Robert Turpin
# 7          0       3                            Mr. John Hatfield Cribb
# 8          0       3                          Mr. John Viktor Bengtsson
# 9          1       3               Master. Frank John William Goldsmith
# 10         0       1                                 Mr. John D Baumann
# 11         1       3                        Miss. Eleanor Ileen Johnson
# 12         0       3                                    Mr. John Bourke
# 13         0       3                              Mr. John Henry Perkin
# 26    male  40.0                        0                        0    8.0500
# 27    male  36.0                        0                        0   26.3875
# 28    male  16.0                        0                        0    8.0500
# 29  female  39.0                        1                        1  110.8833
# 30    male  36.0                        0                        0   40.1250
# 31    male  47.0                        0                        0   15.0000
# 32    male  37.0                        1                        0   26.0000
# 33    male  49.0                        0                        0    0.0000
# 34    male  22.0                        0                        0    7.7500
# 35    male  21.0                        0                        0   16.1000
# 36  female  32.0                        1                        1   15.5000
# 37    male  60.0                        0                        0   26.5500
# 38    male  49.0                        1                        1  110.8833
# 39  female  18.0                        1                        0  227.5250
# 40    male  33.0                        0                        0    7.7750
# 41    male  23.0                        0                        0   13.0000
# 42    male  23.0                        0                        0   14.5000
# 43  female  51.0                        1                        0   77.9583
# 44    male  35.0                        1                        2   23.4500
# 45    male  43.0                        0                        0    6.4500
# 46    male  38.0                        0                        0    0.0000
# 47    male  36.0                        0                        0    6.9500
# 48    male  28.0                        0                        1   33.0000
# 49    male  24.0                        0                        0   13.0000
# 50    male   4.0                        1                        1   11.1333
# 51  female   7.0                        1                        2   23.4500

# %%
# Usando Pandas

titanic_data[titanic_data['Name'].str.contains('John')]
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 41          0       2  Mrs. William John Robert (Dorothy Ann Wonnacot...
# 44          0       3                            Mr. William John Rogers
# 97          1       2                Mrs. John T (Ada Julia Bone) Doling
# 111         0       3                              Mr. David John Barton
# 116         0       2                     Mr. William John Robert Turpin
# 159         0       3                            Mr. John Hatfield Cribb
# 161         0       3                          Mr. John Viktor Bengtsson
# 164         1       3               Master. Frank John William Goldsmith
# 167         0       1                                 Mr. John D Baumann
# 171         1       3                        Miss. Eleanor Ileen Johnson
# 187         0       3                                    Mr. John Bourke
# 211         0       3                              Mr. John Henry Perkin
# 225         1       2                           Mr. William John Mellors
# 226         0       3                               Mr. John Hall Lovell
# 300         0       3                     Mr. William Cahoone Jr Johnson
# 322         0       3                            Mr. George John Jr Sage
# 326         1       3      Mrs. Frank John (Emily Alice Brown) Goldsmith
# 399         0       3                                     Mr. John Adams
# 416         0       2                          Mr. William John Matthews
# 464         0       1                          Mr. John Montgomery Smart
# 524         0       1                                  Mr. John Farthing
# 545         0       3                           Mr. Frank John Goldsmith
# 546         1       2                      Master. John Morgan Jr Davies
# 547         1       1                         Mr. John Borland Jr Thayer
# 560         0       3                                   Mr. John Simmons
# 569         1       1                               Mr. John Irwin Flynn
# 571         0       3                        Mr. Alfred George John Rush
# 578         1       1  Mrs. John Borland (Marian Longstreth Morris) T...
# 580         0       1                                 Mr. John Hugo Ross
# 583         0       2                             Mr. John Denzil Jarvis
# 591         0       2                             Mr. John Henry Chapman
# 594         0       3                                 Mr. Alfred Johnson
# 610         0       3                                    Mr. John Horgan
# 621         0       3                               Mr. David John Bowen
# 654         0       3                       Mrs. John (Catherine) Bourke
